# %% [markdown]
# # Manufacturing Defects (28 points)

# %% [markdown]
# #### Authors

# %%
#import packages here

# %% [markdown]
# #### In previous notebooks you have already explored the importance of manufacturing parameters and curing cycles, specifically the Cure kinetics and Rheokinetics of composite production. The manufacturing process plays a crucial role when we try to guarantee a predictable part quality.
#
# #### In this notebook you will be working on cases for which manufacturing did not reach the expected and predicted quality or, in other words, manufacturing related defects have been detected.
#
# #### Understanding defects is an important part of composite manufacturing. Defects can (and will) occur during most manufacturing processes. You will learn to recognise defects, assess data for components with and without defects, how to deal with shrinkage of polymeric matrices, how to use image analysis to assess defects in fabric weaves, and reflect on the consequences of defects.

# %% [markdown]
# #### Defects in composites can be generally classified as one of the types shown in the graph (Figure 1) below.

# %% [markdown]
# <img src="defect_types.png" width="500" height="340">
#
# Figure 1

# %% [markdown]
# ### Question 1 (3 points)

# %% [markdown]
# #### A case study will be used in this question to start approaching the problem of defects. In this case you will be considering the implosion of the Titan Submersible. Titan imploded during an expedition to the Titanic in June 2023, killing all five occupants Upon news of the fate of Titan, the company closed its Everett office indefinitely. Soon after the implosion, its subsidiary OceanGate Expeditions also suspended operations. From July 2023, OceanGate's websites defaulted to a message advising: "OceanGate has suspended all exploration and commercial operations."
#
# #### As a first step, please read carefully the article provided with this notebook:
# #### Kramer, D., & Otin, S. (2024, July 5). Materials Laboratory Factual Report. National Transportation Safety Board.

# %% [markdown]
# #### Question 1.1: Read Section 1.0 of the report on "Composite hull manufacturing and vessel assembly". Identify and describe an ex-ante monitoring process used by OceanGate and specify the defect type.

# %% [markdown]
# Answer: The hull is equipped with a real-time monitoring system encompassing eight acoustic emission sensors and eight circumferential strain gages. These gages continuously record acoustic events in order to monitor strain behavior of the hull. A threshold was set at 15.6% of the full scale detection range. In view of this, once a signal is captured exceeding the set limit, this arbitrary event is counted as a 'hit'. If the system captures 1000 hits, a color coded warning system displays a yellow warning. Moreover, if the system captures 2000 hits, the warning system displays a red warning, urging the operation to be instantly aborted.
#
# The defect type can't be associated to one specific category; it culminates into a combination of defect types. The main monitored defect types are the matrix- and process related defect types ranging from matrix cracking, fibre-matrix debonding, ply delaminations, adhesive failure to fibre breakage, which can subsequently be traced back to a negligent/faulty manufacturing process.

# %% [markdown]
# #### Question 1.2: Propose an in-situ and an ex-post detection method to identify the defect discussed in Q1.1.

# %% [markdown]
# Answer: Carbon fibres are known for their intrinsic electrical conductivity leading to the following proposition for an in-situ detection method: An electrical resistance/conductivity sensor would detect deflections in the carbon fibre's resistance path which is sensible to internal damage, such as fibre breakage and delamination.
#
# An ex-post detection method would consist in ultrasonic testing, which possibilitates the mapping of internal defects such as voids, delaminations between co-bonded layers and adhesive failure after service.

# %% [markdown]
# #### Question 1.3: The following images (Figure 2a, 2b, 2c) have been discussed in the report. Classify them as fibre, matrix, process or external defects and discuss possible causes of these defects.
#
# Note: Refer to the original pictures in the report for better quality.

# %% [markdown]
# <div style="display: flex; justify-content: center; align-items: center; gap: 2px;">
#     <figure style="text-align: center;">
#         <img src="2a.png" width="600" height="400">
#         <figcaption>Figure 2a</figcaption>
#     </figure>
#     <figure style="text-align: center;">
#         <img src="2b.png" width="600" height="400">
#         <figcaption>Figure 2b</figcaption>
#     </figure>
# </div>
#
# <div style="display: flex; justify-content: center; align-items: center; gap: 2px;">
#     <figure style="text-align: center;">
#         <img src="2c.png" width="600" height="400">
#         <figcaption>Figure 2c</figcaption>
#     </figure>
# </div>

# %% [markdown]
# Answer:
#
# #in report figure 15 cont. and figure 36
#
# *Figure 2a:*
# Circumferential ply exposed: This defect aligns with a process defect. The cause could be traced back to poor surface treatment (degreasing/surface activation) deteriorating the bond strength. A patchy adhesive pattern is noticeable, signaling an uneven spreading of the adhesive and insufficient consolidation pressure during the curing process. This results in an irregular thickness, further diminishing the adhesion capability.
#
# Void: This defect aligns with a process defect. From the perspective of the underlying carbon fibres, voids stem (among other factors) from incomplete and/or contaminated wetting, high curing rates and poor consolidation of the dry fibres during the curing process, hindering outgassing of the trapped air. The latter acts as a stress concentrator, promoting crack nucleation and subsequent growth to critical dimensions.
#
# From the perspective of the adhesive, voids may form for the same reasons listed above. In addition to the above-mentioned factors wrinkles and irregularities of underlying plies prevent the adhesive from flowing evenly, leading to the creation of voids.
#
# Glossy region: This defect aligns with a process and external defect. This anomaly may stem from an under-cured and poorly bonded adhesive. Other likely causes may include contamination with an unknown particle, characterized by the distinct light reflection. An inadequate surface treatment is undoubtedly another cause for this glossy appearance.

# %% [markdown]
# ### Question 2 (2 points)

# %% [markdown]
# #### Free shrinkage and residual stresses
#
# #### Additional defects that can occur in composites include micro-cracks, typically emerging from the combination of residual stresses with thermal cycling or mechanical loading. The primary cause of residual stresses at a micro-mechanical level is the disparity in shrinkage between the fibers and the matrix. Specifically, the polymer matrix tends to undergo considerably more shrinkage (dictated by the coefficient of thermal expansion, CTE) during consolidation and cooling compared to the contracting fibers.
#
# <img src="shrinkage UD.png" width="600" height="400">
#
# Figure 3

# %% [markdown]
# #### In this question we will work towards identifying the differences in shrinkage characteristics of two different thermoplastics (an amorphous and a semi-crystalline polymer). Draw typical storage modulus vs. temperature graphs for both categories. Display them in two different graphs. Explain the evolution of mechanical properties, including: how the storage modulus evolves as a function of temperature. Also identify and explain the differences in relevant temperature points and ranges along the curve - structural range, processing range, free volume evolution, melting and glass transition points between the 2 graphs.

# %% [markdown]
# Answer: (semi-crystalline thermoplastic) ![image.png](attachment:330a067e-bc4a-4f71-8e9a-30f4c7ac8849.png)
#
# (amorphous thermoplastic) ![image.png](attachment:ad17fe5d-1ee3-4c56-a97b-c1ef834992e6.png)
# #REMOVE
#
# **Structural range (below Tg):** The semi-crystalline thermoplastic as well as the amorphous thermoplastic polymer is stiff and brittle in the glass region, given the rotational and displacement barriers hindering any kind of mobility. The chains are 'frozen' in place, which results in a low free volume. The temperature in this case is well below the glass transition temperature Tg. The storage modulus E' is the highest in this region for both thermoplastic polymers, with the semi-crystalline generally being higher compared to its amorphous counterpart. The structural range ends near Tg for both, however the semi-crystalline polymer partially retains some mechanical support from crystalline regions, since those require much higher energy to disbond. For both tanδ is very low, indicating that there is little to no molecular motion lagging behind applied deformation.
#
# **In the vicinity of Tg:** With an increasing temperature, the localized mobility starts increasing coinciding with the increase of free volume. A higher mobility results in the reduction of stiffness, hence E' drops. Both polymers showcase a peak in tanδ, suggesting a high energy dissipation, meaning that molecular motion lags strongly behind applied deformation. The semi-crystalline polymer retains some stiffness due to crystals resulting in a less pronounced drop in E' (slower softening) compared to the amorphous polymer.
#
# **Rubbery plateau:** In this region, the free volume becomes more significant coinciding with a higher chain mobility. E' is low but steady in both thermoplastic polymer types, but higher in semi-crystalline thermoplastic polymers still due to the rigid crystalline regions that provide mechanical support, keeping the material stiffer than the amorphous counterpart. Tanδ of the semi-crystalline thermoplastic polymer steadily increases whereas tanδ of their amorphous counterpart is decreasing.
#
# **Melting temperature (semi-crystalline only):** At this point the crystals melt, resulting in a sharp drop in E', since the chains become fully mobile coinciding with a sharp increase in free volume. Tanδ showcases a second peak, suggestion another spike in energy dissipation upon rupture of crystal bonds. At the same high temperature, the amorphous thermoplastic polymers are already soft, having a relatively low E' and tanδ.
#
# **Processing range**: Both thermoplastic polymers can be processed. Both have a very high free volume and an extremely low E' with the characteristic of the semi-crystalline thermoplastic polymer behaving like their amorphous counterpart, since the crystals melted away and don't provide any more mechanical reinforcement.

# %% [markdown]
# ### Question 3 (4 points)

# %% [markdown]
# #### When dealing with TP consolidation cycles, understanding shrinkage and the potential occurrence of residual stresses in a part is crucial when dealing with the design of consolidation cycles for thermoplastic composites.
#
# #### For the production and autoclave consolidation of a 1 m wide and 2 m long panel using a single unidirectional lamina, two carbon fibre thermoplastic prepregs are under consideration: one with a Polycarbonate matrix and the other with a Polyamide matrix, both utilizing T1000 UD as the reinforcement. It concerns a zero-bleed prepreg with a fibre volume fraction of 55%. The consolidation cycle involves a 200°C dwell, maintained for 1 hour, followed by a cooling phase at 2°C/min until reaching room temperature (20°C). The consolidation cycle is shown in Figure 4 (the heating phase is not shown, as it is not relevant for this question). Equations and assumption that will help you answer the questions, are given below.
#
# #### The longitudinal coefficient of linear thermal expansion for a composite ply can be calculated/estimated as follows:
# $$\alpha_{l} = \frac{(1-\nu_{f})E_{r}\alpha_{r}+ \nu_{f}E_{lf} \alpha_{lf}}{(1-\nu_{f})E_{r} +\nu_{f}E_{lf}}$$
# #### The transverse coefficient of linear thermal expansion for a composite ply can be calculated/estimated as follows:
# $$\alpha_{t} = (1-\nu_{f})\alpha_{r}+ \nu_{f}\alpha_{tf} +(1-\nu_{f})\alpha_{r}\nu_{r} +\nu_{12f}\alpha_{lf}\nu_{f} -\nu_{12}\alpha_{l}$$
#
# #### Where $\nu_{f}$ represents fibre volume content, $E_{r}$ [GPa] Young's modulus of the matrix, $\nu_{r}$ the Poisson ratio of the matrix, $\alpha_{r}$ [1/°C] coefficient of linear thermal expansion of the matrix, $\alpha_{lf}$ [1/°C] and $\alpha_{tf}$ [1/°C] thermal expansion coefficients (CLTE) of fibres in the longitudinal and transverse direction, $E_{lf}$ [GPa] the longitudinal Young's modulus of the fibres, $\nu_{12}$ the in-plane Poisson ratio of the lamina and $\nu_{12f}$ Poisson’s ratio of the fibres.
#
# #### The thermal strain (in longitudinal and transverse direction) can be calculated as follows:
# #### $$\epsilon = \int_{0}^{t} \alpha(t)\Delta Tdt$$

# %% [markdown]
# | Matrix        | Young's modulus [GPa] | Poisson ratio | CLTE [1/°C]          |
# |---------------|-----------------------|---------------|----------------------|
# | Polycarbonate | 1.4                   | 0.37          | $70.2 \cdot 10^{-6}$ |
# | Polyamide 6   | 3                     | 0.39          | $85 \cdot 10^{-6}$   |

# %% [markdown]
# <img src="Cure cycle.jpg" width="1000" height="600">
#
# Figure 4

# %% [markdown]
# #### The following assumptions are made:
# #### - The lamina undergoes free shrinkage
# #### - The properties of the resin and fibers, including volume fraction (vf), Poisson's ratio, and coefficient of linear thermal expansion (CLTE), are non-temperature dependent.
# #### - Poisson ratio of the lamina can be derived using the rule of mixtures

# %% [markdown]
# #### Question 3.1: Given the provided equations, material properties, consolidation cycle, and the listed assumptions, please calculate:
# #### - the composite material's linear coefficient of thermal expansion (in longitudinal and transverse direction).
# #### - the expected strain after reaching room temperature in both length and width direction of the panel
# #### - the percentage of shrinkage in length and width direction of the panel
#
#
# #### Note - You may use Kulkarni R, Ochoa O. Transverse and Longitudinal CTE Measurements of Carbon Fibers and their Impact on Interfacial Residual Stresses in Composites. Journal of Composite Materials. 2006;40(8):733-754. doi:10.1177/0021998305055545 as reference for material data.

# %%
import dataclasses
#
@dataclasses.dataclass
class PolymerProperties:
    name: str
    youngs_modulus: float  # GPa
    poisson_ratio: float
    clte: float  # 1/°C

@dataclasses.dataclass
class FiberProperties:
    name: str
    youngs_modulus: float  # GPa
    poisson_ratio: float
    clte_longitudinal: float  # 1/°C
    clte_transverse: float  # 1/°C

polycarbonate = PolymerProperties(
    name="Polycarbonate",
    youngs_modulus=1.4e9,
    poisson_ratio=0.37,
    clte=70.2e-6
)

polyamide = PolymerProperties(
    name="Polyamide 6",
    youngs_modulus=3e9,
    poisson_ratio=0.39,
    clte=85e-6
)

# Fiber properties
t_1000 = FiberProperties(
    name="T1000 UD",
    youngs_modulus=290e9,  # GPa
    poisson_ratio=0.2,
    clte_longitudinal=5.0e-6,  # 1/°C
    clte_transverse=4.9e-6  # 1/°C
)

vf = 0.55  # fibre volume fraction


def calculate_clte(polymer: PolymerProperties, fiber: FiberProperties, vf: float):
    # $$\alpha_{l} = \frac{(1-\nu_{f})E_{r}\alpha_{r}+ \nu_{f}E_{lf} \alpha_{lf}}{(1-\nu_{f})E_{r} +\nu_{f}E_{lf}}$$
    alpha_l = ((1 - vf) * polymer.youngs_modulus * polymer.clte +
                vf * fiber.youngs_modulus * fiber.clte_longitudinal) / \
               ((1 - vf) * polymer.youngs_modulus + vf * fiber.youngs_modulus)

    # $$\alpha_{t} = (1-\nu_{f})\alpha_{r}+ \nu_{f}\alpha_{tf} +(1-\nu_{f})\alpha_{r}\nu_{r} +\nu_{12f}\alpha_{lf}\nu_{f} -\nu_{12}\alpha_{l}$$
    lamina_poisson_ratio = (1 - vf) * polymer.poisson_ratio + vf * fiber.poisson_ratio

    alpha_t = ((1 - vf) * polymer.clte +
                vf * fiber.clte_transverse +
                (1 - vf) * polymer.clte * polymer.poisson_ratio +
                fiber.poisson_ratio * fiber.clte_longitudinal * vf -
                lamina_poisson_ratio * alpha_l)

    return alpha_l, alpha_t
alpha_l_pc, alpha_t_pc = calculate_clte(polycarbonate, t_1000, vf)
alpha_l_pa, alpha_t_pa = calculate_clte(polyamide, t_1000, vf)
print(f"Longitudinal CTE (Polycarbonate): {alpha_l_pc:.2e} 1/°C")
print(f"Transverse CTE (Polycarbonate): {alpha_t_pc:.2e} 1/°C")

print(f"Longitudinal CTE (Polyamide): {alpha_l_pa:.2e} 1/°C")
print(f"Transverse CTE (Polyamide): {alpha_t_pa:.2e} 1/°C")

# Thermal strain calculation
def calculate_and_report_strain_shrinkage(alpha_l, alpha_t, delta_T):
    epsilon_l = alpha_l * delta_T
    epsilon_t = alpha_t * delta_T
    print(f"Longitudinal strain: {epsilon_l:.2e}")
    print(f"Transverse strain: {epsilon_t:.2e}")

    # Percentage shrinkage
    shrinkage_l = epsilon_l * 100  # %
    shrinkage_t = epsilon_t * 100  # %
    print(f"Longitudinal shrinkage: {shrinkage_l:.2f}%")
    print(f"Transverse shrinkage: {shrinkage_t:.2f}%")

delta_T = 20 - 200  # °C
print("\n----------------------------------------------------------")
print("Polycarbonate:")
calculate_and_report_strain_shrinkage(alpha_l_pc, alpha_t_pc, delta_T)
print("\n----------------------------------------------------------")
print("Polyamide:")
calculate_and_report_strain_shrinkage(alpha_l_pa, alpha_t_pa, delta_T)

# %% [markdown]
# Answer: The answers are printed in the output of the code above.

# %% [markdown]
# #### Question 3.2: Provide insights on the outcomes of question 3.1 from:
# #### - a composites standpoint: this should encompass expectations regarding the direction of highest strain or shrinkage, considerations about the acceptability of dimensional changes, and whether adjustments in the design would be necessary to accommodate these variations.
# #### - a matrix point of view: Offer commentary on the differences between the two thermoplastic resin materials (Polycarbonate and Polyamide), elucidating the reasons behind these differences in terms of their chemical composition, molecular structure, and thermal behaviors and which matrix option you would consider yielding the best mechanical properties or dimensional stability.

# %% [markdown]
# Comment:
#
# From a composites standpoint it makes sense that the largest shrinkage is in the transverse direction. This as the CLTE in transverse direction is dominated by the larger CLTE of the matrix. The longitudinal CLTE is much lower as the CLTE of the fibres is very low, and the fibres are also very stiff. Hence, they resist the shrinkage of the matrix in longitudinal direction. The change in dimensions of the laminate are significant enough to warrant consideration during the design phase, as a shrinkage of roughly 1 centimeter in width of this panel would likely affect the fit of for example fasteners.
#
# TODO: discuss matrix standpoint

# %% [markdown]
# ### Question 4 (2 points)

# %% [markdown]
# #### Residual stresses may emerge during composite manufacturing due to differential strains between the composite part and the tooling as seen in Fig. 5. This issue arises from the coefficient of thermal expansion (CTE) mismatch between the part and the mould/tooling. Residual stresses may potentially lead to lower load carrying capabilities, cracks and areas with resin-rich or resin-starved characteristics if not appropriately addressed.
#
# #### In the previous question, we assumed free shrinkage of the part. When shrinkage of a composite part during manufacturing is constrained by a material (with a different CTE), this shrinkage can be transformed into stress.
#
# #### To effectively design a mold for the panel considered in question 3, three potential materials are under consideration: Aluminum 6061-T6, Invar 36, and CFRP composite. It is assumed that the mold is uniformly heated and monolithic throughout the process.
#
# #### Find the coefficients of thermal expansion for this three possible mould materials (refer to online material databases like MatWeb) and discuss which one will be the most suitable option for the Polycarbonate and Polyamide CF reinforced parts from question 3.
#
# #### Consider the following for the CFRP mold AND laminate -
# #### 1. Both mold and laminate are quasi-isotropic (QI) $[0^\circ, -45^\circ, 45^\circ, 90^\circ]_s$.
# #### 2. Calculate CTE of the QI composites using the modified CLT equations given in Velea, M. N., & Lache, S. (2015). Thermal expansion of composite laminates. Bulletin of the Transilvania University of Brasov. Series I-Engineering Sciences, 25-30.
# #### 3. To simplify the calculations for QI stacking -
#
# $$ V_{1A} = V_{2A} = V_{3A} = V_{4A} =  0$$
#
# $$ A_{16} = A_{26} = 0$$
#
# $$ A_{11} = A_{22}$$
#
# #### 4. $E_1$ = 142000MPa; $E_2$ = 11200MPa; $\nu_{12}$ = $\nu_{21}$ = 0.3; $G_{12}$ = 5000MPa; t = 0.125mm
#
# #### You may also refer to this article: Zobeiry N, Park J, Poursartip A. An infrared thermography-based method for the evaluation of the thermal response of tooling for composites manufacturing. Journal of Composite Materials. 2019;53(10):1277-1290.

# %% [markdown]
# <img src="Mould CTE.PNG" width="800" height="400">
#
# Figure 5: distortion due to shear interaction at tool interface

# %% [markdown]
# Answer:
#
# CTE of Aluminium 6061-T6: 23.0e-06 1/K
#
# CTE of Invar 36: 1.72e-06 1/K
#
# By extracting the values of the different CTEs from question 3, the average effective CTE (combined effect of both longitudinal and transverse CTE) of both composites can be calculated by making use of the following formula: $$\alpha_\mathrm{avg} = \frac{\alpha_l + 2 \alpha_t}{3}$$
#
# $$\alpha_{\mathrm{avg,PC}} \approx 33.7 \times 10^{-6} \ \mathrm{1/K}$$
# $$\alpha_{\mathrm{avg,PA}} \approx 36.3 \times 10^{-6} \ \mathrm{1/K}$$
#
# In order to avoid the creation of pronounced residual stresses and dimensional inaccuracies with deteriorating mechanical properties, the CTE mismatch between tool and ply material should be as low as possible. First, it is important to note that the CTE of both Aluminium 6061-T6 and Invar 36 are assumed isotropic. With that in mind, it becomes evident that the Aluminium 6061-T6 mold provides the most suitable characteristics in terms of minimal CTE mismatch.
#
# As for the CRFP mold and laminate, the code showcased below generates CTE=7.0e-06. Despite its excellent dimensional stability, the CTE mismatch CRFP induces is still higher than Aluminium 6061-T6, meaning the latter is still the preferred option.

# %%
import numpy as np


E1 = 142e3      # MPa
E2 = 11.2e3     # MPa
G12 = 5e3       # MPa
nu12 = 0.3
nu21 = nu12 * E2 / E1
t_ply = 0.125   # mm

alpha_1 = 0.000070  # 1/°C along fiber
alpha_2 = 0.000070  # 1/°C transverse

stacking = [0, -45, 45, 90]
N = len(stacking)

def Q_matrix(E1, E2, G12, nu12, nu21):
    Q11 = E1 / (1 - nu12*nu21)
    Q12 = nu12*E2 / (1 - nu12*nu21)
    Q22 = E2 / (1 - nu12*nu21)
    Q66 = G12
    return np.array([[Q11, Q12, 0],
                     [Q12, Q22, 0],
                     [0,   0,  Q66]])

def transform_Q(Q, theta_deg):
    theta = np.radians(theta_deg)
    c = np.cos(theta)
    s = np.sin(theta)
    T = np.array([[c**2, s**2, 2*c*s],
                  [s**2, c**2, -2*c*s],
                  [-c*s, c*s, c**2 - s**2]])
    T_inv = np.linalg.inv(T)
    return T_inv @ Q @ T_inv.T

A = np.zeros((3,3))

for theta in stacking:
    Q = Q_matrix(E1, E2, G12, nu12, nu21)
    Q_bar = transform_Q(Q, theta)
    A += Q_bar * t_ply

A_inv = np.linalg.inv(A)

# Thermal expansion vector in material coords
alpha_vec = np.array([alpha_1, alpha_2, 0])  # in-plane

# Laminate CTE
alpha_lam = A_inv @ (A @ alpha_vec)  # simplified, since QI approx isotropic

# Average CTE
alpha_avg = (alpha_lam[0] + 2*alpha_lam[1])/3

print(f"Longitudinal CTE: {alpha_lam[0]:.2e} 1/°C")
print(f"Transverse CTE:   {alpha_lam[1]:.2e} 1/°C")
print(f"Average CTE:      {alpha_avg:.2e} 1/°C")

# %% [markdown]
# Comment:

# %% [markdown]
# ## Voids

# %% [markdown]
# #### Voids, one of the most extensively examined categories of manufacturing defects, frequently arise during the fabrication of fibre-reinforced composites. Given their significant impact on the physical and thermomechanical properties of the laminates, they have been subject to thorough investigation. In this notebook the following aspects will be taken into consideration: : the origin of voids, the quantification of voids through image analysis and the implications on the mechanical performance of the composite structure.
#
# #### The graph shown below in Figure 6 (from Processing of Polymer Matrix Composites, P.K. Mallick) shows the correlation between shear strength, void content and autoclave cure cycle. The quality of advanced composites and their mechanical properties are strongly influenced by the void volume content. Therefore, solid knowledge on pressure, flow, temperature and material behaviour is required to properly design manufacturing processes.

# %% [markdown]
# <img src="shear vs. voids.png" width="600" height="800">
#
# Figure 6: Effect of void volume fraction on the interlaminar shear strength of a composite laminate

# %% [markdown]
# ### Question 5 (5 points)

# %% [markdown]
# <img src="Capillary number.png" width="1100" height="400">
#
# Figure 7- Void content versus capillary number
#
# #### Use the concept of capillary number (exemplified in Figure 7 above) to explain the physical difference between capillary flow and viscous flow in a fibrous medium. Comment on the balance needed between capillary number, processing window and void content during manufacturing.
# #### The flow properties influence the final mechanical part properties. How? Include in your answer which kind of flow would be preferred and which type of defects would occur (and where in your fibrous medium).

# %% [markdown]
# Answer:
# Capillary flow takes place when a liquid moves through narrow pores due to the surface tension and adhesive interactions with the solid surface. The flow is driven by a pressure gradient which is created at the curved liquid surface interface.
#
# Viscous flow occurs when the liquid movement through a fibrous medium is dominated by the liquid's resistance to deformation, which means the internal viscosity of the resin controls how easily it can penetrate into narrow pores and spread.
#
# The capillary number is a dimensionless number describing the relative effects of viscous forces to capillary forces in a fluid flow.
#
# The capillary number is expressed as such: $Ca=\frac{\mu U}{\sigma}$
#
# with ${\mu}$ being the resin viscosity, ${U}$ being the flow speed and ${\sigma}$ being the surface tension.
#
# **Low Ca**
#
# A low capillary number corresponds to a flow that is dominated by capillary forces, making it easier to penetrate pores. In view of this, the capillary number should sufficiently low to ensure the resin is drawn into the intra-tow medium by capillary forces.This great characteristic can be highly misleading, because according to the formula shown above, a low Ca corresponds to a low flow speed. This means that the injection flow, which can exceed the processing window to achieve complete impregnation. The processing window may also not be too long, because the excessive flow would 'pool' the intertow spaces creating undesirable stress-concentrating resin-rich areas. A low Ca also coincides with a low-viscosity resin, which is problematic to a degree since it would take too long to cure, making this process more energy-intensive.
#
# **High Ca**
#
# On the other hand, a high capillary number corresponds to a flow that is dominated by viscous forces, making it more difficult to penetrate pores, but instead bypasses them and wets the intertow medium. A positive aspect of a high Ca is the high flow speed, which is beneficial for a short processing time. However, a highly viscous resin struggles to properly flow, creating more voids.
#
# **Conclusion**
#
# Ultimately, it becomes instantly clear that manufacturing is all about balancing trade-offs. Resin and fiber must be compatible such that the flow is dominated by capillarity, while fitting the process into a workable time window, minimizing the void content and preserving mechanical strength. The capillary number must be sufficiently low for the capillary forces to dominate and draw resin into the intratow medium, but sufficiently high to flow in the intertow medium without leaving dry spots. The processing window must be long enough for complete impregnation, but not too long such that stress-concentrating resin-rich areas form. Lastly, inter- and intratow porosity should enable flow while also not compromising mechanical strength.

# %% [markdown]
# ### Question 6 (8 points)

# %% [markdown]
# #### Image Analysis
#
# #### Image analysis is useful when dealing with woven or non-crimp fabric used in advanced composites, particularly for fiber volume content calculations, identifying waviness, and detecting defects. It also plays a crucial role in quality assurance by identifying and characterizing defects such as voids, wrinkles, and variations in resin distribution of the composite products. These defects can substantially affect the structural integrity of the final composite product.
#
# #### Image analysis techniques also add a quantitative dimension to defect assessment, offering measurements of defect size, shape, and distribution. This quantitative data is invaluable for optimising manufacturing processes and upholding stringent quality control standards.
#
# #### A top view (2D) picture has been extracted from a 3D image of a woven fabric laminate and reported below.
# #### The darker regions in the image can be identified as voids. Given the critical requirement for aerospace structures to maintain an acceptable volumetric void content of less than 2%, it becomes crucial to quantify void content rather than relying on qualitative observations of the image.
#
# #### For the next few sub-questions, the following keywords can be kept in mind to better answer the questions: Image Opening and Closing, Erosion, Dilation, Filtering, Denoising and Sum of 2 Gaussian Distributions.
#
# #### Question 6.1: Write a script to calculate the void content of the image provided. Then, comment on whether this percentage is acceptable or not.

# %% [markdown]
# <img src="slice_0130.jpeg" width="700" height="700">
#
# Figure 8

# %%
# python
from PIL import Image
import numpy as np
from scipy.ndimage import gaussian_filter, binary_opening
import matplotlib.pyplot as plt

def calculate_void_content(img_path, threshold_brightness=66, gauss_sigma=0.8, clean_structure=np.ones((3, 3))):
    # Load grayscale image
    img = Image.open(img_path).convert('L')
    arr = np.array(img)  # 2D uint8

    # Smooth to reduce speckle noise
    arr_smooth = gaussian_filter(arr, sigma=gauss_sigma)

    # Void mask: dark regions
    mask = arr_smooth < threshold_brightness
    # Clean small specks
    mask = binary_opening(mask, structure=clean_structure)

    # Void content (2D)
    void_pixels = mask.sum()
    total_pixels = mask.size
    void_percent = 100.0 * void_pixels / total_pixels
    return void_percent

# Parameters
img_path = 'slice_0130.jpeg'
out_path = 'slice_0130_pink.png'
threshold_brightness = 66   # tune this to detect voids (0-255)
gauss_sigma = 0.8
clean_structure = np.ones((3, 3))
pink = np.array([255, 105, 180], dtype=np.uint8)  # RGB pink

# Calculate void content
void_percent = calculate_void_content(img_path, threshold_brightness, gauss_sigma, clean_structure)
print(f"Void content: {void_percent:.2f}%")

# Create RGB image from grayscale
rgb = np.stack([arr, arr, arr], axis=-1).astype(np.uint8)
overlay = np.zeros_like(rgb)
overlay[:] = pink

# Apply overlay where mask is True (alpha blend if alpha < 1)
rgb[mask] = overlay[mask]

# Prepare histogram data
brightness = arr.ravel()
bins = np.arange(257)  # 0..256 for uint8
counts, bin_edges = np.histogram(brightness, bins=bins)
bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])

# --- Figure 1: show pink-overlay image (custom size) ---
fig1, ax1 = plt.subplots(figsize=(6, 6), dpi=100)  # size for first figure
ax1.imshow(rgb)
ax1.set_title('Voids highlighted in pink')
ax1.axis('off')
fig1.tight_layout()

# --- Figure 2: histogram with log y-axis (separate size) ---
fig2, ax2 = plt.subplots(figsize=(8, 4), dpi=100)  # different size for second figure
# Use counts>0 mask to avoid log(0) plotting issues
mask_counts = counts > 0
ax2.plot(bin_centers[mask_counts], counts[mask_counts], lw=1, color='gray')
ax2.fill_between(bin_centers[mask_counts], counts[mask_counts], color='gray', alpha=0.25)
ax2.set_yscale('log')
ax2.axvline(threshold_brightness, color='red', linestyle='--', label=f'threshold={threshold_brightness}')
ax2.set_xlabel('Brightness (0-255)')
ax2.set_ylabel('Pixel count (log scale)')
ax2.set_title('Brightness histogram (log y)')
ax2.legend()
ax2.grid(True, which='both', alpha=0.25)
fig2.tight_layout()

plt.show()
# Out:
# Void content: 0.27%

# %% [markdown]
# Comment:
# - We do some denoising by filtering the image with a Gaussian filter.
# - We create a mask of pixels below a certain brightness threshold, which we consider as voids. This is tuned visually by looking at the newly generated image that shows the areas detected as voids in pink.
# - The end result is a void content of 0.27%, well below the 2% threshold for aerospace applications.

# %% [markdown]
# #### Question 6.2: Now expand your previous code and apply the same technique to estimate the overall void volume content (in 3D) of the laminate. The folder provided with this notebook contains 107 slices obtained with microtomography. Using your algorithm from question 6.1 calculate the void content of each slice and report all the values in a single graph as a function of the slice number. Finally, calculate the average void content (in 3D) and comment on the difference/similarity with your answer in question 6.1.
# #### Please also comment on the applicability of 2D void content measurements to represent the overall void content of a product.

# %% [markdown]
# Comment:

# %% [markdown]
# #### Question 6.3: What are the primary characterization techniques employed for void content evaluation? List three techniques. Could you outline the advantages and disadvantages of each technique? Additionally, which of these techniques, and any others covered in lectures, can be applied proactively (ex ante) to prevent void formation?

# %% [markdown]
# Answer:

# %% [markdown]
# #### Question 6.4: Image analysis on the image provided above (Figure 8, question 6.1) can also be useful to obtain an estimation of fibre volume fraction and matrix content.
# #### To do this, first obtain and display the histogram of the woven fabric laminate, manipulate the initial image to obtain a better thresholding and describe what you did in terms of manipulation of the image, display the newly obtained histogram and then use this data to quantify the fibre and matrix content for the image provided.
# #### Finally, comment on the fibre volume content you obtained.

# %% [markdown]
# Comment:

# %% [markdown]
# ### Question 7 (4 points)

# %% [markdown]
# #### As you have seen in the case study above, defects in composites have the potential to lead to significant consequences. In the next question, you will analyze two Force-Strain datasets for two similar samples. The samples are joined through continuous ultrasonic welding. Their cross-sectional micrographs are displayed below, and can be seen in Figure 9 and 10 respectively.
# <img src="SLS_1.jpg" width="400" height="240">
#
# Figure 9
#
# <img src="SLS_2.jpg" width="400" height="240">
#
# Figure 10
# #### Question 7.1: Examine Figure 9 and 10. One of these images shows a consolidated sample, the other one shows a defective sample. Please explain which figure belongs to which sample. Also provide a small discussion on the expected differences, and why these differences would occur.

# %% [markdown]
# Answer:

# %% [markdown]
# #### Question 7.2: Attached are two datasets of Single Lap Shear tests, both with identical test settings. Each dataset contains the results of 5 samples. One of the datasets is derived from a reasonably well consolidated sample, while the other dataset coming from a defective sample. Plot and analyze the Stress-Strain graphs. Conclude which of the sets is of the defective sample, and explain the difference in plotted curves.

# %% [markdown]
# Comment:

# %% [markdown]
# #### Question 7.3: From your results of Q7.2, you should be able to derive that the elastic moduli are approximately similar for all samples. Explain why this is the case.

# %% [markdown]
# Answer:
